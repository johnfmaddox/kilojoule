# %% [markdown]
# # Example 9.2: Otto Cycle
#
# *John F. Maddox, Ph.D., P.E.<br>
# University of Kentucky - Paducah Campus<br>
# ME 321: Engineering Thermodynamics II<br>*

# %% [markdown]
# ## Problem Statement
# An Otto cycle with compression ratio of $8$ starts its compression stroke from $p_1=1\ \text{bar}$, $T_1=300\ \text{K}$.  The maximum temperature after combustion is $1200\ \text{K}$.
# Determine:
# * (a) $p$-$v$ diagram
# * (b) $T$-$s$ diagram
# * (c) $T$,$p$ at each state
# * (d) $q_{in}$
# * (e) $w_{net}$
# * (f) $\eta_{th}$

# %% [markdown]
# ## Solution
#
# __[Video Explanation](https://uky.yuja.com/V/Video?v=3074244&node=10465167&a=685460354&autoplay=1)__

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_K import *

air = realfluid.Properties('Air', unit_system='SI_K')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
# %%showcalc
# T[1] = Quantity(300,'K')
# p[1] = Quantity(1,'bar')
# T_max = Quantity(1200,'K')
# r = Quantity(8,'')
# Out:
# \begin{aligned}
#   {T}_{ 1 } &=  300\ \mathrm{K}
# \end{aligned}
# \begin{aligned}
#   {p}_{ 1 } &=  1\ \mathrm{bar}  = 1\times 10^{5}\ \mathrm{Pa}
# \end{aligned}
# \begin{aligned}
#   T_{max} &=  1200\ \mathrm{K}
# \end{aligned}
# \begin{aligned}
#   r &=  8\
# \end{aligned}

# %% [markdown]
# ### Assumptions
#   - Treat air as a real fluid
#   - Variable Specific Heat

# %% [markdown]
# #### (c) $T$,$p$ at each state

# %%
# %%showcalc
# # Isentropic Compression $1\to2$
# s[1] = air.s(T=T[1],p=p[1])
# v[1] = air.v(T=T[1],p=p[1])
# v[2] = v[1]/r
# s[2] = s[1]
# T[2] = air.T(s=s[2],v=v[2])
# p[2] = air.p(s=s[2],v=v[2])
#
# # Isochoric Heat Addition $2\to3$
# v[3] = v[2]
# T[3] = T_max
# p[3] = air.p(T=T[3],v=v[3])
#
# # Isentropic Expansion $3\to4$
# s[3] = air.s(T=T[3],v=v[3])
# s[4] = s[3]
# v[4] = r*v[3]
# T[4] = air.T(v=v[4],s=s[4])
# p[4] = air.p(v=v[4],s=s[4])
# Out:
#  Isentropic Compression $1\to2$
# \begin{aligned}
#   {s}_{ 1 } &=  \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = {T}_{ 1 }, \mathrm{ p } = {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = 300\ \mathrm{K}, \mathrm{ p } = 1\times 10^{5}\ \mathrm{Pa} \right) = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{aligned}
# \begin{aligned}
#   {v}_{ 1 } &=  \mathrm{ \underset{ air }{ v } }\left( \mathrm{ T } = {T}_{ 1 }, \mathrm{ p } = {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ v } }\left( \mathrm{ T } = 300\ \mathrm{K}, \mathrm{ p } = 1\times 10^{5}\ \mathrm{Pa} \right) = 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   {v}_{ 2 } &=  \frac{ {v}_{ 1 } }{ r } \\
#     &= \frac{ 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 8\ }\\
#     &= 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   {s}_{ 2 } &=  {s}_{ 1 }  = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{aligned}
# \begin{aligned}
#   {T}_{ 2 } &=  \mathrm{ \underset{ air }{ T } }\left( \mathrm{ s } = {s}_{ 2 }, \mathrm{ v } = {v}_{ 2 } \right)  = \mathrm{ \underset{ air }{ T } }\left( \mathrm{ s } = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 675.53\ \mathrm{K}
# \end{aligned}
# \begin{aligned}
#   {p}_{ 2 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ s } = {s}_{ 2 }, \mathrm{ v } = {v}_{ 2 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ s } = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 1.8141\times 10^{6}\ \mathrm{Pa}
# \end{aligned}
#  Isochoric Heat Addition $2\to3$
# \begin{aligned}
#   {v}_{ 3 } &=  {v}_{ 2 }  = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   {T}_{ 3 } &=  T_{max}  = 1200\ \mathrm{K}
# \end{aligned}
# \begin{aligned}
#   {p}_{ 3 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ v } = {v}_{ 3 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 3.2294\times 10^{6}\ \mathrm{Pa}
# \end{aligned}
#  Isentropic Expansion $3\to4$
# \begin{aligned}
#   {s}_{ 3 } &=  \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ v } = {v}_{ 3 } \right)  = \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{aligned}
# \begin{aligned}
#   {s}_{ 4 } &=  {s}_{ 3 }  = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{aligned}
# \begin{aligned}
#   {v}_{ 4 } &=   r  \cdot  {v}_{ 3 }  \\
#     &=  8\  \cdot  0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \\
#     &= 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   {T}_{ 4 } &=  \mathrm{ \underset{ air }{ T } }\left( \mathrm{ v } = {v}_{ 4 }, \mathrm{ s } = {s}_{ 4 } \right)  = \mathrm{ \underset{ air }{ T } }\left( \mathrm{ v } = 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}, \mathrm{ s } = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 577.77\ \mathrm{K}
# \end{aligned}
# \begin{aligned}
#   {p}_{ 4 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ v } = {v}_{ 4 }, \mathrm{ s } = {s}_{ 4 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ v } = 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}, \mathrm{ s } = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 1.9278\times 10^{5}\ \mathrm{Pa}
# \end{aligned}

# %%
states.display()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>T</th>
#       <th>p</th>
#       <th>v</th>
#       <th>s</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>K</th>
#       <th>Pa</th>
#       <th>m³/kg</th>
#       <th>kJ/K/kg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>300.000000</td>
#       <td>1.000000e+05</td>
#       <td>0.860882</td>
#       <td>3.890501</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>675.533302</td>
#       <td>1.814107e+06</td>
#       <td>0.107610</td>
#       <td>3.890501</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1200.000000</td>
#       <td>3.229436e+06</td>
#       <td>0.107610</td>
#       <td>4.370191</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>577.773976</td>
#       <td>1.927848e+05</td>
#       <td>0.860882</td>
#       <td>4.370191</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### (a) $p$-$v$ diagram

# %%
pv = air.pv_diagram()
for i in [1,2,3,4]:
    pv.plot_state(states[i],label_loc='east')
pv.plot_process(states[1],states[2], path='isentropic',label='isentropic',pos=.8)
pv.plot_process(states[2],states[3], path='isochoric')
pv.plot_process(states[3],states[4], path='isentropic',label='isentropic')
pv.plot_process(states[4],states[1], path='isochoric');

pv.plot_isotherm(T[3])
pv.plot_isotherm(T[1],pos=.1);

# %% [markdown]
# #### (b) $T$-$s$ diagram

# %%
Ts = air.Ts_diagram()
for i in [1,2,3,4]:
    Ts.plot_state(states[i], label_loc='north east')
Ts.plot_process(states[1],states[2], path='isentropic')
Ts.plot_process(states[2],states[3], path='isochoric',label='isochoric')
Ts.plot_process(states[3],states[4], path='isentropic')
Ts.plot_process(states[4],states[1], path='isochoric',label='isochoric');

Ts.plot_isobar(p[3],pos=.1)
Ts.plot_isobar(p[1]);

# %% [markdown]
# #### (d) $q_{in}$

# %%
# %%showcalc
# # Heat transfer only takes place from $2\to3$ and from $4\to1$
# u[2] = air.u(T=T[2],p=p[2])
# u[3] = air.u(T=T[3],p=p[3])
#
# q_2_to_3 = u[3]-u[2]
# q_in = q_2_to_3
# Out:
#  Heat transfer only takes place from $2\to3$ and from $4\to1$
# \begin{aligned}
#   {u}_{ 2 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 2 }, \mathrm{ p } = {p}_{ 2 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 675.53\ \mathrm{K}, \mathrm{ p } = 1.8141\times 10^{6}\ \mathrm{Pa} \right) = 618.43\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   {u}_{ 3 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ p } = {p}_{ 3 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ p } = 3.2294\times 10^{6}\ \mathrm{Pa} \right) = 1059.0\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   q_{2\to{}3} &=   {u}_{ 3 } - {u}_{ 2 }  \\
#     &=  1059.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 618.43\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   q_{in} &=  q_{2\to{}3}  = 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}

# %% [markdown]
# #### (e) $w_{net}$

# %%
# %%showcalc
# u[1] = air.u(T=T[1],p=p[1])
# u[4] = air.u(T=T[4],p=p[4])
# q_4_to_1 = u[4]-u[1]
# q_out = q_4_to_1
#
# w_net = q_in-q_out
# Out:
# \begin{aligned}
#   {u}_{ 1 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 1 }, \mathrm{ p } = {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 300\ \mathrm{K}, \mathrm{ p } = 1\times 10^{5}\ \mathrm{Pa} \right) = 340.21\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   {u}_{ 4 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 4 }, \mathrm{ p } = {p}_{ 4 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 577.77\ \mathrm{K}, \mathrm{ p } = 1.9278\times 10^{5}\ \mathrm{Pa} \right) = 544.12\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   q_{4\to{}1} &=   {u}_{ 4 } - {u}_{ 1 }  \\
#     &=  544.12\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 340.21\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   q_{out} &=  q_{4\to{}1}  = 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}
# \begin{aligned}
#   w_{net} &=   q_{in} - q_{out}  \\
#     &=  440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 236.62\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{aligned}

# %% [markdown]
# #### (f)  $\eta_{th}$

# %%
# %%showcalc
# # Thermal efficiency
# eta_th = w_net/q_in
# Out:
#  Thermal efficiency
# \begin{aligned}
#   \eta_{th} &=  \frac{ w_{net} }{ q_{in} } \\
#     &= \frac{ 236.62\ \frac{\mathrm{kJ}}{\mathrm{kg}} }{ 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\
#     &= 0.53712\
# \end{aligned}

# %%
Summary()
Summary(['q_in','w_net','eta_th']);
# Out:
# \begin{aligned}{ T_{max} }&={ 1200\ \mathrm{K} }&{ \eta_{th} }&={ 0.53712\ }&{ q_{2\to{}3} }&={ 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ q_{4\to{}1} }&={ 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}} }&{ q_{in} }&={ 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} }&{ q_{out} }&={ 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ r }&={ 8\ }&{ w_{net} }&={ 236.62\ \frac{\mathrm{kJ}}{\mathrm{kg}} }&{  }\end{aligned}
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>T</th>
#       <th>p</th>
#       <th>v</th>
#       <th>u</th>
#       <th>s</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>K</th>
#       <th>Pa</th>
#       <th>m³/kg</th>
#       <th>kJ/kg</th>
#       <th>kJ/K/kg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>300.000000</td>
#       <td>1.000000e+05</td>
#       <td>0.860882</td>
#       <td>340.212594</td>
#       <td>3.890501</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>675.533302</td>
#       <td>1.814107e+06</td>
#       <td>0.107610</td>
#       <td>618.429558</td>
#       <td>3.890501</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1200.000000</td>
#       <td>3.229436e+06</td>
#       <td>0.107610</td>
#       <td>1058.961027</td>
#       <td>4.370191</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>577.773976</td>
#       <td>1.927848e+05</td>
#       <td>0.860882</td>
#       <td>544.124530</td>
#       <td>4.370191</td>
#     </tr>
#   </tbody>
# </table>
# \begin{aligned}{ q_{in} }&={ 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ w_{net} }&={ 236.62\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ \eta_{th} }&={ 0.53712\ }\\{  }\end{aligned}
