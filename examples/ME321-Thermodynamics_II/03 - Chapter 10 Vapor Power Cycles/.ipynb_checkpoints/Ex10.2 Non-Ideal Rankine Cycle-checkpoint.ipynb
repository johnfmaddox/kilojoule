# %% [markdown]
# # Example 10.2: Non-Ideal Rankine Cycle
#
# *John F. Maddox, Ph.D., P.E.<br>
# University of Kentucky - Paducah Campus<br>
# ME 321: Engineering Thermodynamics II<br>*

# %% [markdown]
# ## Problem Statement
# A Rankine cycle operates with water as the working fluid with a turbine inlet pressure of 3 MPa, a condenser pressure of 15 kPa, and no superheat in the boiler.  For For isentropic efficiencies of $\eta_t=0.8$ and $\eta_p=0.6$  and $\dot{W}_\text{Net}=1\ \mathrm{MW}$ Find:
# * (a) Mass flow rate of steam (kg/s)
# * (b) Boiler heat transfer (MW)
# * (c) Thermal efficiency of the cycle
# * (d) Sketch a $T$-$s$ diagram of the cycle
#
# ![image.png](attachment:90020869-2a7e-4630-a16e-bfdb4c7d56fe.png)

# %% [markdown]
# ## Solution
#
# __[Video Explanation](https://uky.yuja.com/V/Video?v=3074261&node=10465193&a=1519284077&autoplay=1)__

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_C import *
   
water = realfluid.Properties('Water')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
p[3] = Quantity(3.0,'MPa')         # Turbine inlet pressure
p[1] = p[4] = Quantity(15.0,'kPa') # Condenser pressure
Wdot_net = Quantity(1,'MW')        # Net power 
eta_t = 0.8                        # Turbine isentropic efficiency
eta_p = 0.6                        # Pump isentropic efficiency
  
Summary();
# Out:
# \[\begin{aligned}{ \dot{W}_{net} }&={  1\ \mathrm{MW}  }&{  }\end{aligned}\]
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>p</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>kPa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3000.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Assumptions
# - Non-ideal work devices
# - No superheat: saturated vapor at boiler exit
# - Single phase into pump: saturated liquid at condenser exit
# - Isobaric heat exchagners
# - Negligible changes in kinetic energy
# - Negligible changes in potential energy

# %%
x[3] = 1      # No superheat
x[1] = 0      # Single phase into pump
p[2] = p[3]   # isobaric heat exchanger

Summary();
# Out:
# \[\begin{aligned}{ \dot{W}_{net} }&={  1\ \mathrm{MW}  }&{  }\end{aligned}\]
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>p</th>
#       <th>x</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>kPa</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>15.0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3000.0</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3000.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.0</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### (a) Mass flow rate

# %%
#### State 1)
T[1] = water.T(p[1],x[1])
v[1] = water.v(p[1],x[1])
h[1] = water.h(p[1],x[1])
s[1] = water.s(p[1],x[1])

#### 1-2) Non-ideal compression
# Isentropic compression
p['2s'] = p[2]
s['2s'] = s[1]
T['2s'] = water.T(p['2s'],s['2s'])
h['2s'] = water.h(p['2s'],s['2s'])
v['2s'] = water.v(p['2s'],s['2s'])
# Actual compression
h[2] = h[1] + (h['2s']-h[1])/eta_p
T[2] = water.T(p[2],h=h[2])
v[2] = water.v(p[2],h=h[2])
s[2] = water.s(p[2],h=h[2])
w_1_to_2 = h[1]-h[2]

#### 2-3) Isobaric heat addition
T[3] = water.T(p[3],x[3])
v[3] = water.v(p[3],x[3])
h[3] = water.h(p[3],x[3])
s[3] = water.s(p[3],x[3])

#### 3-4) Non-ideal expansion
# Isentropic Expansion
p['4s'] = p[4]
s['4s'] = s[3]
T['4s']= water.T(p['4s'],s['4s'])
v['4s']= water.v(p['4s'],s['4s'])
h['4s'] = water.h(p['4s'],s['4s'])
x['4s'] = water.x(p['4s'],s['4s'])
# Actual expansion
h[4] = h[3] - eta_t*(h[3]-h['4s'])
T[4] = water.T(p[4],h=h[4])
v[4] = water.v(p[4],h=h[4])
s[4] = water.s(p[4],h=h[4])
x[4] = water.x(p[4],h=h[4])
w_3_to_4 = h[3]-h[4]

#### Mass flow rate
w_net = w_1_to_2 + w_3_to_4
mdot = Wdot_net/w_net
mdot.ito('kg/s') 

Calculations();
# Out:
# ### State 1)
# \[
#   \begin{aligned}
#     { T_{1} }&={ \mathrm{\underset{water}{T}}\left(p_{1} , x_{1}\right) } = { 53.969\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { v_{1} }&={ \mathrm{\underset{water}{v}}\left(p_{1} , x_{1}\right) } = { 0.001014\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { h_{1} }&={ \mathrm{\underset{water}{h}}\left(p_{1} , x_{1}\right) } = { 225.94\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{1} }&={ \mathrm{\underset{water}{s}}\left(p_{1} , x_{1}\right) } = { 0.75486\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
# ### 1-2) Non-ideal compression
#  Isentropic compression
# \[
#   \begin{aligned}
#     { p_{2s} }&={ p_{2} } = { 3000.0\ \mathrm{kPa}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{2s} }&={ s_{1} } = { 0.75486\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { T_{2s} }&={ \mathrm{\underset{water}{T}}\left(p_{2s} , s_{2s}\right) } = { 54.084\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { h_{2s} }&={ \mathrm{\underset{water}{h}}\left(p_{2s} , s_{2s}\right) } = { 228.97\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { v_{2s} }&={ \mathrm{\underset{water}{v}}\left(p_{2s} , s_{2s}\right) } = { 0.0010128\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
#  Actual compression
# \[
#   \begin{aligned}{ h_{2} }&={ h_{1} + \frac{h_{2s} - h_{1}}{\eta_{p}} }\\
#     &={ \left( 225.94\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) + \frac{\left( 228.97\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) - \left( 225.94\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right)}{ 0.6 } }\\
#     &={  230.99\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { T_{2} }&={ \mathrm{\underset{water}{T}}\left(p_{2} , \mathrm{h}=h_{2}\right) } = { 54.567\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { v_{2} }&={ \mathrm{\underset{water}{v}}\left(p_{2} , \mathrm{h}=h_{2}\right) } = { 0.001013\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{2} }&={ \mathrm{\underset{water}{s}}\left(p_{2} , \mathrm{h}=h_{2}\right) } = { 0.76102\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}{ w_{1\to{}2} }&={ h_{1} - h_{2} }\\
#     &={ \left( 225.94\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) - \left( 230.99\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) }\\
#     &={  -5.0417\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# ### 2-3) Isobaric heat addition
# \[
#   \begin{aligned}
#     { T_{3} }&={ \mathrm{\underset{water}{T}}\left(p_{3} , x_{3}\right) } = { 233.85\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { v_{3} }&={ \mathrm{\underset{water}{v}}\left(p_{3} , x_{3}\right) } = { 0.066664\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { h_{3} }&={ \mathrm{\underset{water}{h}}\left(p_{3} , x_{3}\right) } = { 2803.2\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{3} }&={ \mathrm{\underset{water}{s}}\left(p_{3} , x_{3}\right) } = { 6.1856\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
# ### 3-4) Non-ideal expansion
#  Isentropic Expansion
# \[
#   \begin{aligned}
#     { p_{4s} }&={ p_{4} } = { 15.0\ \mathrm{kPa}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{4s} }&={ s_{3} } = { 6.1856\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { T_{4s} }&={ \mathrm{\underset{water}{T}}\left(p_{4s} , s_{4s}\right) } = { 53.969\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { v_{4s} }&={ \mathrm{\underset{water}{v}}\left(p_{4s} , s_{4s}\right) } = { 7.5037\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { h_{4s} }&={ \mathrm{\underset{water}{h}}\left(p_{4s} , s_{4s}\right) } = { 2002.4\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { x_{4s} }&={ \mathrm{\underset{water}{x}}\left(p_{4s} , s_{4s}\right) } = { 0.74884\  }
#   \end{aligned}
# \]
#  Actual expansion
# \[
#   \begin{aligned}{ h_{4} }&={ - \eta_{t} \left(h_{3} - h_{4s}\right) + h_{3} }\\
#     &={ -  0.8  \left(\left( 2803.2\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) - \left( 2002.4\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right)\right) + \left( 2803.2\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) }\\
#     &={  2162.6\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { T_{4} }&={ \mathrm{\underset{water}{T}}\left(p_{4} , \mathrm{h}=h_{4}\right) } = { 53.969\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { v_{4} }&={ \mathrm{\underset{water}{v}}\left(p_{4} , \mathrm{h}=h_{4}\right) } = { 8.18\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{4} }&={ \mathrm{\underset{water}{s}}\left(p_{4} , \mathrm{h}=h_{4}\right) } = { 6.6751\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { x_{4} }&={ \mathrm{\underset{water}{x}}\left(p_{4} , \mathrm{h}=h_{4}\right) } = { 0.81634\  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}{ w_{3\to{}4} }&={ h_{3} - h_{4} }\\
#     &={ \left( 2803.2\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) - \left( 2162.6\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) }\\
#     &={  640.57\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# ### Mass flow rate
# \[
#   \begin{aligned}{ w_{net} }&={ w_{1\to{}2} + w_{3\to{}4} }\\
#     &={ \left( -5.0417\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) + \left( 640.57\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) }\\
#     &={  635.53\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}{ \dot{m} }&={ \frac{\dot{W}_{net}}{w_{net}} }\\
#     &={ \frac{\left( 1\ \mathrm{MW} \right)}{\left( 635.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right)} }\\
#     &={  1.5735\ \frac{\mathrm{kg}}{\mathrm{s}}  }
#   \end{aligned}
# \]

# %% [markdown]
# #### (b) Boiler heat transfer (MW)

# %%
#### Boiler First Law
q_2_to_3 = h[3]-h[2]
Qdot_in = mdot*q_2_to_3

Calculations();
# Out:
# ### Boiler First Law
# \[
#   \begin{aligned}{ q_{2\to{}3} }&={ h_{3} - h_{2} }\\
#     &={ \left( 2803.2\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) - \left( 230.99\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) }\\
#     &={  2572.2\ \frac{\mathrm{kJ}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}{ \dot{Q}_{in} }&={ \dot{m} q_{2\to{}3} }\\
#     &={ \left( 1.5735\ \frac{\mathrm{kg}}{\mathrm{s}} \right) \left( 2572.2\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) }\\
#     &={  4047.3\ \frac{\mathrm{kJ}}{\mathrm{s}}  }
#   \end{aligned}
# \]

# %% [markdown]
# #### (c) Thermal efficiency

# %%
eta_th = Wdot_net/Qdot_in
eta_th.ito('') 

Calculations();
# Out:
# \[
#   \begin{aligned}{ \eta_{th} }&={ \frac{\dot{W}_{net}}{\dot{Q}_{in}} }\\
#     &={ \frac{\left( 1\ \mathrm{MW} \right)}{\left( 4047.3\ \frac{\mathrm{kJ}}{\mathrm{s}} \right)} }\\
#     &={  0.24708\  }
#   \end{aligned}
# \]

# %% [markdown]
# #### (d) Diagrams

# %%
pv = water.pv_diagram()

for state in [1,2,3,4]:
    v[state] = water.v(p[state],h=h[state])

pv.plot_state(states[1],label_loc='west')
pv.plot_state(states[2],label_loc='north west')
pv.plot_state(states[3],label_loc='north east')
pv.plot_state(states[4],label_loc='south')

pv.plot_process(states[1],states[2],path='nonideal',label='pump')
pv.plot_process(states[2],states[3],path='isobaric',label='boiler')
pv.plot_process(states[3],states[4],path='nonideal',label='turbine')
pv.plot_process(states[4],states[1],path='isobaric',label='condenser');

# %%
Ts = water.Ts_diagram()
Ts.plot_isobar(p[3],label=f'{p[3]}',pos=.9)
Ts.plot_isobar(p[4],label=f'{p[4]}',pos=.9)

Ts.plot_state(states[1],label_loc='south east')
Ts.plot_state(states[2],label_loc='north west')
Ts.plot_state(states[3],label_loc='east')
Ts.plot_state(states[4],label_loc='east')
    
Ts.plot_process(states[1],states[2],path='isentropic',arrow=False)
Ts.plot_process(states[2],states[3],path='isobaric',label='boiler')
Ts.plot_process(states[3],states[4],path='isentropic',label='turbine')
Ts.plot_process(states[4],states[1],path='isobaric',label='condenser');
Ts.plot_process(states[3],states['4s'],path='isentropic',linestyle='dashed');
