# %% [markdown]
# ## Problem Statement
# Air is compressed isentropically form $T_1=250\ \text{K}$, $p_1=1\ \text{bar}$ to $T_2=400\ \text{K}$
# * (a) What is the compression ratio
# * (b) What is the final pressure

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_C import *

# This treats the air as a "real fluid", i.e. not an ideal gas
air = realfluid.Properties('Air', unit_system='SI_C')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
T[1] = Quantity(250,'K')
p[1] = Quantity(1,'bar')
T[2] = Quantity(400,'K')

display.Calculations(locals(),comments=True);
# Out:
# \[
#   \begin{aligned}
#     { T_{1} }&={ \left( 250\,\mathrm{K} \right) } = { -23.15\ \mathrm{°C}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { p_{1} }&={ \left( 1\,\mathrm{bar} \right) } = { 100.0\ \mathrm{kPa}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { T_{2} }&={ \left( 400\,\mathrm{K} \right) } = { 126.85\ \mathrm{°C}  }
#   \end{aligned}
# \]

# %% [markdown]
# #### Assumptions (Real Fluid)
# * Not Ideal Gas
# * Variable specific heat
# * Adiabatic
# * Negligible changes in kinetic and potential energies

# %% [markdown]
# #### (a) Compression Ratio

# %%
# Properties at inlet
v[1] = air.v(T[1],p[1])
s[1] = air.s(T[1],p[1])

# Isentropic
s[2] = s[1]

# Specific volume at exit
v[2] = air.v(T[2],s[2])

# Compression ratio
r = v[1]/v[2]

display.Calculations(locals(),comments=True);
# Out:
#  Properties at inlet
# \[
#   \begin{aligned}
#     { v_{1} }&={ \mathrm{\underset{air}{v}}\left(T_{1} , p_{1}\right) } = { 0.71694\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
# \[
#   \begin{aligned}
#     { s_{1} }&={ \mathrm{\underset{air}{s}}\left(T_{1} , p_{1}\right) } = { 3.7071\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
#  Isentropic
# \[
#   \begin{aligned}
#     { s_{2} }&={ s_{1} } = { 3.7071\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }
#   \end{aligned}
# \]
#  Specific volume at exit
# \[
#   \begin{aligned}
#     { v_{2} }&={ \mathrm{\underset{air}{v}}\left(T_{2} , s_{2}\right) } = { 0.22172\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}  }
#   \end{aligned}
# \]
#  Compression ratio
# \[
#   \begin{aligned}{ r }&={ \frac{v_{1}}{v_{2}} }\\
#     &={ \frac{\left( 0.71694\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right)}{\left( 0.22172\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right)} }\\
#     &={  3.2335\  }
#   \end{aligned}
# \]

# %% [markdown]
# #### (b) Final Pressure

# %%
# Pressure at exit
p[2] = air.p(T[2],s[2])

# Pressure ratio
r_p = p[2]/p[1]

display.Calculations(locals(),comments=True);
# Out:
#  Pressure at exit
# \[
#   \begin{aligned}
#     { p_{2} }&={ \mathrm{\underset{air}{p}}\left(T_{2} , s_{2}\right) } = { 518.36\ \mathrm{kPa}  }
#   \end{aligned}
# \]
#  Pressure ratio
# \[
#   \begin{aligned}{ r_{p} }&={ \frac{p_{2}}{p_{1}} }\\
#     &={ \frac{\left( 518.36\ \mathrm{kPa} \right)}{\left( 100.0\ \mathrm{kPa} \right)} }\\
#     &={  5.1836\  }
#   \end{aligned}
# \]

# %%
pv = air.pv_diagram()

pv.plot_state(states[1])
pv.plot_state(states[2])

pv.plot_process(states[1],states[2],path='isentropic',label='isentropic');

pv.plot_isotherm(T[1],xcoor=.3)
pv.plot_isotherm(T[2],xcoor=.3)
pv.plot_isobar(p[1],pos=0.5)
pv.plot_isobar(p[2],pos=0.5)
pv.plot_isenthalp(air.h(T[2],p[2]));

# %%
Ts = air.Ts_diagram()

Ts.plot_state(states[1],label_loc='north west')
Ts.plot_state(states[2])

Ts.plot_process(states[1],states[2],path='isentropic',label='isentropic');

Ts.plot_isotherm(T[1])
Ts.plot_isotherm(T[2])
Ts.plot_isobar(p[1])
Ts.plot_isobar(p[2],pos=0.5)
Ts.plot_isochor(v[1])
Ts.plot_isochor(v[2],pos=.2);

# %%
display.Summary(locals());
# Out:
# \[\begin{aligned}{ r }&={  3.2335\  }&{ r_{p} }&={  5.1836\  }&{  }\end{aligned}\]
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>T</th>
#       <th>p</th>
#       <th>v</th>
#       <th>s</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>°C</th>
#       <th>kPa</th>
#       <th>m³/kg</th>
#       <th>kJ/K/kg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>-23.15</td>
#       <td>100.000000</td>
#       <td>0.716943</td>
#       <td>3.70713</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>126.85</td>
#       <td>518.363299</td>
#       <td>0.221721</td>
#       <td>3.70713</td>
#     </tr>
#   </tbody>
# </table>

# %%
display.Summary(locals(),['r','r_p']);
# Out:
# \[\begin{aligned}{ r }&={  3.2335\  }\\{ r_{p} }&={  5.1836\  }\\{  }\end{aligned}\]
